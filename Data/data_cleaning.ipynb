# %%
import pandas as pd

# %%
data = pd.read_csv('Wuzzuf_Nakuri_summary.csv')

# %%
data
# Out:
#       Unnamed: 0                                    id
# 0              0  09c527f4-3fb9-402e-92e3-e802866cfc72  \
# 1              1  0739174a-2443-4d3f-b64e-5c34ece26876
# 2              2  083ebcbc-bc00-4f5f-8398-15585ad35582
# 3              3  a5fd0169-fc57-4b43-9778-8d22bc151b88
# 4              4  2aad8a20-7d90-4147-aa51-c592e1001aac
# ...          ...                                   ...
# 1428          45                          041122500663
# 1429          46                          261222500879
# 1430          47                          160323500710
# 1431          48                          160323500744
# 1432          49                          160323501163
#
#                                                   title
# 0                                         Sales Manager  \
# 1                                 Cybersecurity Officer
# 2                                            IT Manager
# 3                          Senior PHP Laravel Developer
# ...

# %%
data['id'] = data.index + 1

# %%
data
# Out:
#       Unnamed: 0    id                                              title
# 0              0     1                                      Sales Manager  \
# 1              1     2                              Cybersecurity Officer
# 2              2     3                                         IT Manager
# 3              3     4                       Senior PHP Laravel Developer
# 4              4     5                        Backend Developer - Laravel
# ...          ...   ...                                                ...
# 1428          45  1429                     Data Engineer-Data Integration
# 1429          46  1430  Content & Experience Cloud and Webcenter Senio...
# 1430          47  1431                        Senior Analytics Consultant
# 1431          48  1432                            Senior PP/QM Consultant
# 1432          49  1433                               Senior SAP Developer
#
#                                             description
# ...

# %%
data = data[['id','title','description']]

# %%
data
# Out:
#         id                                              title
# 0        1                                      Sales Manager  \
# 1        2                              Cybersecurity Officer
# 2        3                                         IT Manager
# 3        4                       Senior PHP Laravel Developer
# 4        5                        Backend Developer - Laravel
# ...    ...                                                ...
# 1428  1429                     Data Engineer-Data Integration
# 1429  1430  Content & Experience Cloud and Webcenter Senio...
# 1430  1431                        Senior Analytics Consultant
# 1431  1432                            Senior PP/QM Consultant
# 1432  1433                               Senior SAP Developer
#
#                                             description
# 0     SALES MANAGER JOB DESCRIPTIONResponsible for p...
# 1     Implementing security measures based on busine...
# ...

# %%
data.to_csv('Wuzzuf_Nakuri_summary_cleaned.csv', index=False)
